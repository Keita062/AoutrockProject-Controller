# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv(r"C:\GitHub\AoutrockProject-Controller\taisen\model_data\train_data.csv")
test_df = pd.read_csv(r"C:\GitHub\AoutrockProject-Controller\taisen\model_data\test_data.csv")

# %%
train_df.columns
# Out:
# Index(['delta_t_mean', 'delta_t_std', 'delta_t_max', 'delta_t_q25',
#        'delta_t_q75', 'X_count', 'X_run_length_avg', 'Y_count',
#        'Y_run_length_avg', 'B_count', 'B_run_length_avg', 'A_count',
#        'A_run_length_avg', 'RB_count', 'RB_run_length_avg', 'LB_count',
#        'LB_run_length_avg', 'RT_count', 'RT_run_length_avg', 'LT_count',
#        'LT_run_length_avg', 'RStick_count', 'RStick_run_length_avg',
#        'LStick_count', 'LStick_run_length_avg', 'SELECT_count',
#        'SELECT_run_length_avg', 'START_count', 'START_run_length_avg',
#        'CenterArrow_count', 'CenterArrow_run_length_avg', 'UpArrow_count',
#        'UpArrow_run_length_avg', 'DownArrow_count', 'DownArrow_run_length_avg',
#        'LeftArrow_count', 'LeftArrow_run_length_avg', 'RightArrow_count',
#        'RightArrow_run_length_avg', 'UpRightArrow_count',
#        'UpRightArrow_run_length_avg', 'UpLeftArrow_count',
#        'UpLeftArrow_run_length_avg', 'DownRightArrow_count',
# ...
